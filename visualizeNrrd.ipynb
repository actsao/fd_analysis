# %%
import nrrd

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import csv, os

# %%
data, _ = nrrd.read('048_pect_phfirst_013114_wholeLungVesselParticles_height_1_5_ctSigma_1_0.nrrd')

np.shape(data)
# Out:
# (622, 622, 466)

# %%
# %matplotlib widget
plt.imshow(data[:, :, 233])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
